# %%
import pandas as pd
import numpy as np

# %%
cols_to_use = []
for i in range(0,20):
    cols_to_use.append(i)
benign = pd.DataFrame(pd.read_csv("benign.csv"))
benign1 = pd.DataFrame(pd.read_csv("benign1.csv", usecols=cols_to_use))
benign2 = pd.DataFrame(pd.read_csv("benign2.csv", usecols=cols_to_use))
benign3 = pd.DataFrame(pd.read_csv("benign3.csv", usecols=cols_to_use))
benign4 = pd.DataFrame(pd.read_csv("benign4.csv", usecols=cols_to_use))

# %%
b = benign.append(benign1)

# %%
b = b.append(benign2)
b = b.append(benign3)
b = b.append(benign4)
b
# Out:
#              Time       Source-IP Method-Type          Path  \
# 0    1.539845e+09       127.0.0.1         GET             /
# 1    1.539845e+09       127.0.0.1         GET             /
# 2    1.539845e+09       127.0.0.1         GET  /favicon.ico
# 3    1.539845e+09       127.0.0.1        POST             /
# 4    1.539845e+09       127.0.0.1        POST             /
# 5    1.539845e+09       127.0.0.1         GET      /?btn2=2
# 6    1.539845e+09       127.0.0.1        POST             /
# 7    1.539845e+09       127.0.0.1         GET      /?btn8=8
# 8    1.539845e+09       127.0.0.1        POST             /
# 9    1.539845e+09       127.0.0.1         GET      /?btn2=2
# 10   1.539845e+09       127.0.0.1        POST             /
# 11   1.539845e+09       127.0.0.1         GET      /?btn2=2
# 12   1.539845e+09       127.0.0.1         GET             /
# 13   1.539845e+09       127.0.0.1        POST             /
# 14   1.539845e+09       127.0.0.1        POST             /
# ...

# %%
b = b.reset_index(drop=True)

# %%
b
# Out:
#               Time       Source-IP Method-Type          Path  \
# 0     1.539845e+09       127.0.0.1         GET             /
# 1     1.539845e+09       127.0.0.1         GET             /
# 2     1.539845e+09       127.0.0.1         GET  /favicon.ico
# 3     1.539845e+09       127.0.0.1        POST             /
# 4     1.539845e+09       127.0.0.1        POST             /
# 5     1.539845e+09       127.0.0.1         GET      /?btn2=2
# 6     1.539845e+09       127.0.0.1        POST             /
# 7     1.539845e+09       127.0.0.1         GET      /?btn8=8
# 8     1.539845e+09       127.0.0.1        POST             /
# 9     1.539845e+09       127.0.0.1         GET      /?btn2=2
# 10    1.539845e+09       127.0.0.1        POST             /
# 11    1.539845e+09       127.0.0.1         GET      /?btn2=2
# 12    1.539845e+09       127.0.0.1         GET             /
# 13    1.539845e+09       127.0.0.1        POST             /
# ...

# %%
userAgentBenign = b["User-Agent"].unique()

# %%
userAgentBenign
# Out:
# array(['Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML. like Gecko) Chrome/69.0.3497.100 Safari/537.36',
#        'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:62.0) Gecko/20100101 Firefox/62.0',
#        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML. like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299',
#        'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; Touch; USPortal; rv:11.0) like Gecko',
#        'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko',
#        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML. like Gecko) Chrome/64.0.3282.140 Safari/537.36 Edge/17.17134',
#        'Mozilla/5.0 (iPhone; CPU iPhone OS 11_4 like Mac OS X) AppleWebKit/605.1.15 (KHTML. like Gecko) Version/11.0 Mobile/15E148 Safari/604.1',
#        'Mozilla/5.0 (Linux; Android 8.0.0) AppleWebKit/537.36 (KHTML. like Gecko) Version/4.0 Chrome/69.0.3497.100 Mobile Safari/537.36',
# ...

# %%
malware = pd.DataFrame(data = pd.read_csv("malware.csv"))
malware1 = pd.DataFrame(data=pd.read_csv("malware-2.csv"))

# %%
malware["User-Agent"].append(malware1["User-Agent"]).unique()
# Out:
# array(['Mozilla/4.0 (compatible; MSIE 6.1; Windows XP)',
#        'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.1) Gecko/20090718 Firefox/3.5.1',
#        'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.2; Win64; x64; Trident/4.0)',
#        'Opera/9.80 (Windows NT 5.2; U; ru) Presto/2.5.22 Version/10.51',
#        'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; SV1; .NET CLR 2.0.50727; InfoPath.2)',
#        'Mozilla/5.0 (Windows; U; MSIE 7.0; Windows NT 6.0; en-US)',
#        'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; InfoPath.2)',
#        'Mozilla/5.0 (X11; U; Linux x86_64; en-US; rv:1.9.1.3) Gecko/20090913 Firefox/3.5.3',
#        'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; SLCC1; .NET CLR 2.0.50727; .NET CLR 1.1.4322; .NET CLR 3.5.30729; .NET CLR 3.0.30729)',
# ...

# %%
malware1["User-Agent"].unique()
# Out:
# array(['Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML. like Gecko) Chrome/69.0.3497.100 Safari/537.36',
#        'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.1) Gecko/20090718 Firefox/3.5.1',
#        'Mozilla/5.0 (X11; U; Linux x86_64; en-US; rv:1.9.1.3) Gecko/20090913 Firefox/3.5.3',
#        'Mozilla/5.0 (Windows; U; MSIE 7.0; Windows NT 6.0; en-US)',
#        'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/532.1 (KHTML. like Gecko) Chrome/4.0.219.6 Safari/532.1',
#        'Mozilla/4.0 (compatible; MSIE 6.1; Windows XP)',
#        'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; InfoPath.2)',
#        'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; SV1; .NET CLR 2.0.50727; InfoPath.2)',
#        'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; SLCC1; .NET CLR 2.0.50727; .NET CLR 1.1.4322; .NET CLR 3.5.30729; .NET CLR 3.0.30729)',
# ...

# %%
malware = malware.append(malware1)

# %%
malware = malware.reset_index(drop=True)
malware
# Out:
#      Accept                  Accept-Charset Accept-Encoding Accept-Language  \
# 0       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 1       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 2       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 3       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 4       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 5       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 6       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 7       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 8       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 9       NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# 10      NaN  ISO-8859-1.utf-8;q=0.7.*;q=0.7        identity             NaN
# ...
